# %%
import pickle

# %%
with open('data/label.pkl', 'rb') as f:
    label = pickle.load(f)

# %%
a = [j for i,j in label.items()]

# %%
sum(a[1724:]),len(a)
# Out:
# (393, 2464)

# %%
import os 
a = os.listdir('linker_smi/')
c = []
for i in a:
    with open('linker_smi/'+i) as f:
        b = f.readlines()
        c.append(b)
        print(b)
# Out:
# ['CCCNC(=O)CO']
# ['CCOCCOCCOCCOCCOCCC=O']
# ['COCCOCCOCCOCCOCCOC1=CC=C(/C=N/NC=O)C=C1']
# ['C#CC']
# ['CCCCCCNC(=O)CCCCCN']
# ['CC']
# ['NCCCCCCCNC(=O)CO']
# ['CCCCC=O']
# ['CCOCCOCC']
# ['O=CCN1CCC(CNC=O)CC1']
# ['CC(=O)NCCOCCN1C=C(C)N=N1']
# ['NCCCCCCCCCCCC=O']
# ['CCCCCCC']
# ['CCOCCOCCOCCOCCOC']
# ['CCCCCCNC(=O)CO']
# ['COCCN1CCN(C2=CC=C(C=O)C=C2)CC1']
# ['COCC1=CN(CCN)N=N1']
# ['CCCCCCCCC(N)=O']
# ['CCCCCOCCCOC']
# ['CCCCOC1=CC=C(/C=N/NC=O)C=C1']
# ['C#CC1=CC=C(N2CCN(CCC)CC2)N=C1']
# ['CCC1=CN(CCOCCOCCO)N=N1']
# ['CCCCC1=CN(CCCCCCCCCO)N=N1']
# ['CCOCCOCCN']
# ['COCCOCCOCCOCCN(C)C(=O)CCN']
# ['CC1=CN(CCCCCC=O)N=N1']
# ['NCCOCCOCCOCCNC=O']
# ['CCO']
# ['CCCNC(=O)CCOCCOCCOCCOCCOCCOCC']
# ['CCCOCC']
# ['CCCCCCCCCCO']
# ['CCN']
# ['CCOCCOCCOCCOCC']
# ['CCCCCCC']
# ['CCCNCCOCCOC']
# ['CCCCCC=O']
# ['CCCCCCC']
# ['O=CCOCCOCCOCCO']
# ['CCNC(C)=O']
# ['CCCCCCCCCC']
# ['CCCCCCN']
# ['CCCCCCOCCCCOCCCCOCCCCOCCCCC']
# ['CCCCCC']
# ['CCOCCOCC=O']
# ['CCCN']
# ['COCCCOCCN']
# ['CCCCCC(N)=O']
# ...

# %%
d = [len(x[0]) for x in c]

# %%
max(d)
# Out:
# 52
